# %%
import pandas as pd
from auth.spotify_auth import authenticate_user
import pprint

# %%
def get_top_artists(sp, time_range="medium_term", limit=50):
    """
    Fetch the current user's top artists from Spotify and return a pandas DataFrame.

    Parameters:
        sp: Authenticated spotipy.Spotify client
        time_range (str): One of 'short_term', 'medium_term', or 'long_term'
        limit (int): Number of artists to retrieve (max 50)

    Returns:
        pd.DataFrame: DataFrame containing:
            - artist_id
            - artist_name
            - genres (comma-separated)
            - popularity
            - followers
            - spotify_url
    """

    # FETCH TOP ARTISTS
    results = sp.current_user_top_artists(time_range=time_range, limit=limit)
    top_artists = results.get('items', [])


    # NORMALIZE NESTED JSON TO DATAFRAME
    df = pd.json_normalize(top_artists)

    return df

# %%
sp = authenticate_user()
df = get_top_artists(sp, time_range="medium_term", limit=50)
df
# Out:
#                                      genres  \
# 0                                     [rap]
# 1                               [dream pop]
# 2                             [melodic rap]
# 3                                        []
# 4                [dark r&b, r&b, trap soul]
# 5             [hip hop, west coast hip hop]
# 6                                        []
# 7        [uk drill, drill, uk grime, grime]
# 8                                        []
# 9                                        []
# 10                                       []
# 11                                       []
# 12                            [melodic rap]
# 13       [grime, uk grime, uk drill, drill]
# 14                                    [rap]
# 15                             [sexy drill]
# 16                                       []
# 17                                       []
# 18                                       []
# 19                                  [indie]
# 20                             [indie folk]
# 21                                       []
# 22                                    [rap]
# 23                                    [rap]
# 24                            [melodic rap]
# 25  [dancehall, soca, afrobeats, afroswing]
# 26                                       []
# 27                                       []
# 28                         [trap soul, r&b]
# 29                                       []
# 30                 [rap, melodic rap, trap]
# 31                                    [r&b]
# 32                                       []
# 33                                    [edm]
# 34       [bollywood, hindi pop, desi, sufi]
# 35                                       []
# 36                                       []
# 37                           [ambient folk]
# 38                                       []
# 39         [afrobeats, dancehall, afrobeat]
# 40                                       []
# 41                              [dancehall]
# 42                        [dancehall, soca]
# 43    [afrobeats, afro r&b, alté, afrobeat]
# 44  [brooklyn drill, drill, new york drill]
# 45                                       []
# 46                                       []
# 47                                       []
# 48                             [indie folk]
# 49                               [dark r&b]
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/3TVXtAsR1In...  3TVXtAsR1Inumwj472S9r4
# 1   https://api.spotify.com/v1/artists/1QAJqy2dA3i...  1QAJqy2dA3ihHBFIHRphZj
# 2   https://api.spotify.com/v1/artists/31W5EY0aAly...  31W5EY0aAly4Qieq6OFu6I
# 3   https://api.spotify.com/v1/artists/0iEtIxbK0Kx...  0iEtIxbK0KxaSlF7G42ZOp
# 4   https://api.spotify.com/v1/artists/2HPaUgqeutz...  2HPaUgqeutzr3jx5a9WyDV
# 5   https://api.spotify.com/v1/artists/2YZyLoL8N0W...  2YZyLoL8N0Wb9xBt1NhZWg
# 6   https://api.spotify.com/v1/artists/2jku7tDXc6X...  2jku7tDXc6XoB6MO2hFuqg
# 7   https://api.spotify.com/v1/artists/5H4yInM5zmH...  5H4yInM5zmHqpKIoMNAx4r
# 8   https://api.spotify.com/v1/artists/3gIRvgZssIb...  3gIRvgZssIb9aiirIg0nI3
# 9   https://api.spotify.com/v1/artists/1Xyo4u8uXC1...  1Xyo4u8uXC1ZmMpatF05PJ
# 10  https://api.spotify.com/v1/artists/5f7VJjfbwm5...  5f7VJjfbwm532GiveGC0ZK
# 11  https://api.spotify.com/v1/artists/5nvWOyAkfNg...  5nvWOyAkfNgVLKESq4fOj2
# 12  https://api.spotify.com/v1/artists/2hlmm7s2ICU...  2hlmm7s2ICUX0LVIhVFlZQ
# 13  https://api.spotify.com/v1/artists/6Ip8FS7vWT1...  6Ip8FS7vWT1uKkJSweANQK
# 14  https://api.spotify.com/v1/artists/1RyvyyTE3xz...  1RyvyyTE3xzB2ZywiAwp0i
# 15  https://api.spotify.com/v1/artists/0jPHHnU8GUW...  0jPHHnU8GUWEF7rwPE9osY
# 16  https://api.spotify.com/v1/artists/6ltzsmQQbmd...  6ltzsmQQbmdoHHbLZ4ZN25
# 17  https://api.spotify.com/v1/artists/4Gso3d4CscC...  4Gso3d4CscCijv0lmajZWs
# 18  https://api.spotify.com/v1/artists/5JMLG56F1X5...  5JMLG56F1X5mFmWNmS0iAp
# 19  https://api.spotify.com/v1/artists/0NIPkIjTV8m...  0NIPkIjTV8mB795yEIiPYL
# 20  https://api.spotify.com/v1/artists/1zO3MgzmcwZ...  1zO3MgzmcwZLLNUQqeU2XH
# 21  https://api.spotify.com/v1/artists/3MZsBdqDrRT...  3MZsBdqDrRTJihTHQrO6Dq
# 22  https://api.spotify.com/v1/artists/20sxb77xiYe...  20sxb77xiYeusSH8cVdatc
# 23  https://api.spotify.com/v1/artists/6l3HvQ5sa6m...  6l3HvQ5sa6mXTsMTB19rO5
# 24  https://api.spotify.com/v1/artists/7rkW85dBwwr...  7rkW85dBwwrJtlHRDkJDAC
# 25  https://api.spotify.com/v1/artists/1LKo6ZA3RNv...  1LKo6ZA3RNvKtLa6zDu32S
# 26  https://api.spotify.com/v1/artists/4tuJ0bMpJh0...  4tuJ0bMpJh08umKkEXKUI5
# 27  https://api.spotify.com/v1/artists/4lhUHpVOXmk...  4lhUHpVOXmkEBGGHV71QCh
# 28  https://api.spotify.com/v1/artists/2EMAnMvWE2e...  2EMAnMvWE2eb56ToJVfCWs
# 29  https://api.spotify.com/v1/artists/4G9NDjRyZFD...  4G9NDjRyZFDlJKMRL8hx3S
# 30  https://api.spotify.com/v1/artists/50co4Is1HCE...  50co4Is1HCEo8bhOyUWKpn
# 31  https://api.spotify.com/v1/artists/7bXgB6jMjp9...  7bXgB6jMjp9ATFy66eO08Z
# 32  https://api.spotify.com/v1/artists/5SXuuuRpukk...  5SXuuuRpukkTvsLuUknva1
# 33  https://api.spotify.com/v1/artists/7CajNmpbOov...  7CajNmpbOovFoOoasH2HaY
# 34  https://api.spotify.com/v1/artists/1wRPtKGflJr...  1wRPtKGflJrBx9BmLsSwlU
# 35  https://api.spotify.com/v1/artists/31TPClRtHm2...  31TPClRtHm23RisEBtV3X7
# 36  https://api.spotify.com/v1/artists/7FGAlyRveFm...  7FGAlyRveFmDqEaAwqEzIT
# 37  https://api.spotify.com/v1/artists/0rZp7G3gIH6...  0rZp7G3gIH6WkyeXbrZnGi
# 38  https://api.spotify.com/v1/artists/1URnnhqYAYc...  1URnnhqYAYcrqrcwql10ft
# 39  https://api.spotify.com/v1/artists/1V6rvT87qMQ...  1V6rvT87qMQvo6HAixjlpY
# 40  https://api.spotify.com/v1/artists/2RQXRUsr4IW...  2RQXRUsr4IW1f3mKyKsy4B
# 41  https://api.spotify.com/v1/artists/3Isy6kedDrg...  3Isy6kedDrgPYoTS1dazA9
# 42  https://api.spotify.com/v1/artists/5sK8BsvyDl4...  5sK8BsvyDl4TFA6KaBf8or
# 43  https://api.spotify.com/v1/artists/687cZJR45JO...  687cZJR45JO7jhk1LHIbgq
# 44  https://api.spotify.com/v1/artists/0eDvMgVFoNV...  0eDvMgVFoNV3TpwtrVCoTj
# 45  https://api.spotify.com/v1/artists/2h93pZq0e7k...  2h93pZq0e7k5yf4dywlkpM
# 46  https://api.spotify.com/v1/artists/0QHgL1lAIqA...  0QHgL1lAIqAw0HtD7YldmP
# 47  https://api.spotify.com/v1/artists/69tiO1fG8VW...  69tiO1fG8VWduDl3ji2qhI
# 48  https://api.spotify.com/v1/artists/7IAFAOtc9kT...  7IAFAOtc9kTYNTizhLSWM6
# 49  https://api.spotify.com/v1/artists/7LVC96BEVGu...  7LVC96BEVGugTAp38AajV6
#
#                                                images                    name  \
# 0   [{'height': 640, 'url': 'https://i.scdn.co/ima...                   Drake
# 1   [{'height': 640, 'url': 'https://i.scdn.co/ima...    Cigarettes After Sex
# 2   [{'height': 640, 'url': 'https://i.scdn.co/ima...  A Boogie Wit da Hoodie
# 3   [{'height': 640, 'url': 'https://i.scdn.co/ima...            Metro Boomin
# 4   [{'height': 640, 'url': 'https://i.scdn.co/ima...           PARTYNEXTDOOR
# 5   [{'height': 640, 'url': 'https://i.scdn.co/ima...          Kendrick Lamar
# 6   [{'height': 640, 'url': 'https://i.scdn.co/ima...              Tory Lanez
# 7   [{'height': 640, 'url': 'https://i.scdn.co/ima...             Central Cee
# 8   [{'height': 640, 'url': 'https://i.scdn.co/ima...           Jeremy Zucker
# 9   [{'height': 640, 'url': 'https://i.scdn.co/ima...              The Weeknd
# 10  [{'height': 640, 'url': 'https://i.scdn.co/ima...                Lil Baby
# 11  [{'height': 640, 'url': 'https://i.scdn.co/ima...            Montell Fish
# 12  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   Gunna
# 13  [{'height': 640, 'url': 'https://i.scdn.co/ima...                    Dave
# 14  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  Future
# 15  [{'height': 640, 'url': 'https://i.scdn.co/ima...         Jordan Adetunji
# 16  [{'height': 640, 'url': 'https://i.scdn.co/ima...              Lord Huron
# 17  [{'height': 640, 'url': 'https://i.scdn.co/ima...             Don Toliver
# 18  [{'height': 640, 'url': 'https://i.scdn.co/ima...          Chelsea Cutler
# 19  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 Wallows
# 20  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 Hazlett
# 21  [{'height': 640, 'url': 'https://i.scdn.co/ima...                    Joji
# 22  [{'height': 640, 'url': 'https://i.scdn.co/ima...               Meek Mill
# 23  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 J. Cole
# 24  [{'height': 640, 'url': 'https://i.scdn.co/ima...                     NAV
# 25  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 Kranium
# 26  [{'height': 640, 'url': 'https://i.scdn.co/ima...           Gracie Abrams
# 27  [{'height': 640, 'url': 'https://i.scdn.co/ima...             Chance Peña
# 28  [{'height': 640, 'url': 'https://i.scdn.co/ima...           Bryson Tiller
# 29  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   sombr
# 30  [{'height': 640, 'url': 'https://i.scdn.co/ima...              Young Thug
# 31  [{'height': 640, 'url': 'https://i.scdn.co/ima...             Chris Brown
# 32  [{'height': 640, 'url': 'https://i.scdn.co/ima...               Baby Keem
# 33  [{'height': 640, 'url': 'https://i.scdn.co/ima...           Calvin Harris
# 34  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  Pritam
# 35  [{'height': 640, 'url': 'https://i.scdn.co/ima...       Justin Timberlake
# 36  [{'height': 640, 'url': 'https://i.scdn.co/ima...                Them & I
# 37  [{'height': 640, 'url': 'https://i.scdn.co/ima...               Novo Amor
# 38  [{'height': 640, 'url': 'https://i.scdn.co/ima...               21 Savage
# 39  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 Ayo Jay
# 40  [{'height': 640, 'url': 'https://i.scdn.co/ima...              Noah Kahan
# 41  [{'height': 640, 'url': 'https://i.scdn.co/ima...               Sean Paul
# 42  [{'height': 640, 'url': 'https://i.scdn.co/ima...            Charly Black
# 43  [{'height': 640, 'url': 'https://i.scdn.co/ima...                    Tems
# 44  [{'height': 640, 'url': 'https://i.scdn.co/ima...               Pop Smoke
# 45  [{'height': 640, 'url': 'https://i.scdn.co/ima...             Frank Ocean
# 46  [{'height': 640, 'url': 'https://i.scdn.co/ima...               DJ Khaled
# 47  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 Mt. Joy
# 48  [{'height': 640, 'url': 'https://i.scdn.co/ima...            Hollow Coves
# 49  [{'height': 640, 'url': 'https://i.scdn.co/ima...                   Lithe
#
#     popularity    type                                    uri  \
# 0           97  artist  spotify:artist:3TVXtAsR1Inumwj472S9r4
# 1           86  artist  spotify:artist:1QAJqy2dA3ihHBFIHRphZj
# 2           78  artist  spotify:artist:31W5EY0aAly4Qieq6OFu6I
# 3           87  artist  spotify:artist:0iEtIxbK0KxaSlF7G42ZOp
# 4           87  artist  spotify:artist:2HPaUgqeutzr3jx5a9WyDV
# 5           95  artist  spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg
# 6           82  artist  spotify:artist:2jku7tDXc6XoB6MO2hFuqg
# 7           83  artist  spotify:artist:5H4yInM5zmHqpKIoMNAx4r
# 8           67  artist  spotify:artist:3gIRvgZssIb9aiirIg0nI3
# 9           96  artist  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 10          88  artist  spotify:artist:5f7VJjfbwm532GiveGC0ZK
# 11          76  artist  spotify:artist:5nvWOyAkfNgVLKESq4fOj2
# 12          87  artist  spotify:artist:2hlmm7s2ICUX0LVIhVFlZQ
# 13          78  artist  spotify:artist:6Ip8FS7vWT1uKkJSweANQK
# 14          92  artist  spotify:artist:1RyvyyTE3xzB2ZywiAwp0i
# 15          68  artist  spotify:artist:0jPHHnU8GUWEF7rwPE9osY
# 16          78  artist  spotify:artist:6ltzsmQQbmdoHHbLZ4ZN25
# 17          87  artist  spotify:artist:4Gso3d4CscCijv0lmajZWs
# 18          66  artist  spotify:artist:5JMLG56F1X5mFmWNmS0iAp
# 19          73  artist  spotify:artist:0NIPkIjTV8mB795yEIiPYL
# 20          65  artist  spotify:artist:1zO3MgzmcwZLLNUQqeU2XH
# 21          79  artist  spotify:artist:3MZsBdqDrRTJihTHQrO6Dq
# 22          75  artist  spotify:artist:20sxb77xiYeusSH8cVdatc
# 23          86  artist  spotify:artist:6l3HvQ5sa6mXTsMTB19rO5
# 24          74  artist  spotify:artist:7rkW85dBwwrJtlHRDkJDAC
# 25          59  artist  spotify:artist:1LKo6ZA3RNvKtLa6zDu32S
# 26          88  artist  spotify:artist:4tuJ0bMpJh08umKkEXKUI5
# 27          73  artist  spotify:artist:4lhUHpVOXmkEBGGHV71QCh
# 28          82  artist  spotify:artist:2EMAnMvWE2eb56ToJVfCWs
# 29          84  artist  spotify:artist:4G9NDjRyZFDlJKMRL8hx3S
# 30          86  artist  spotify:artist:50co4Is1HCEo8bhOyUWKpn
# 31          89  artist  spotify:artist:7bXgB6jMjp9ATFy66eO08Z
# 32          77  artist  spotify:artist:5SXuuuRpukkTvsLuUknva1
# 33          88  artist  spotify:artist:7CajNmpbOovFoOoasH2HaY
# 34          89  artist  spotify:artist:1wRPtKGflJrBx9BmLsSwlU
# 35          83  artist  spotify:artist:31TPClRtHm23RisEBtV3X7
# 36          60  artist  spotify:artist:7FGAlyRveFmDqEaAwqEzIT
# 37          73  artist  spotify:artist:0rZp7G3gIH6WkyeXbrZnGi
# 38          88  artist  spotify:artist:1URnnhqYAYcrqrcwql10ft
# 39          55  artist  spotify:artist:1V6rvT87qMQvo6HAixjlpY
# 40          85  artist  spotify:artist:2RQXRUsr4IW1f3mKyKsy4B
# 41          84  artist  spotify:artist:3Isy6kedDrgPYoTS1dazA9
# 42          65  artist  spotify:artist:5sK8BsvyDl4TFA6KaBf8or
# 43          77  artist  spotify:artist:687cZJR45JO7jhk1LHIbgq
# 44          79  artist  spotify:artist:0eDvMgVFoNV3TpwtrVCoTj
# 45          88  artist  spotify:artist:2h93pZq0e7k5yf4dywlkpM
# 46          76  artist  spotify:artist:0QHgL1lAIqAw0HtD7YldmP
# 47          72  artist  spotify:artist:69tiO1fG8VWduDl3ji2qhI
# 48          67  artist  spotify:artist:7IAFAOtc9kTYNTizhLSWM6
# 49          72  artist  spotify:artist:7LVC96BEVGugTAp38AajV6
#
#                                 external_urls.spotify followers.href  \
# 0   https://open.spotify.com/artist/3TVXtAsR1Inumw...           None
# 1   https://open.spotify.com/artist/1QAJqy2dA3ihHB...           None
# 2   https://open.spotify.com/artist/31W5EY0aAly4Qi...           None
# 3   https://open.spotify.com/artist/0iEtIxbK0KxaSl...           None
# 4   https://open.spotify.com/artist/2HPaUgqeutzr3j...           None
# 5   https://open.spotify.com/artist/2YZyLoL8N0Wb9x...           None
# 6   https://open.spotify.com/artist/2jku7tDXc6XoB6...           None
# 7   https://open.spotify.com/artist/5H4yInM5zmHqpK...           None
# 8   https://open.spotify.com/artist/3gIRvgZssIb9ai...           None
# 9   https://open.spotify.com/artist/1Xyo4u8uXC1ZmM...           None
# 10  https://open.spotify.com/artist/5f7VJjfbwm532G...           None
# 11  https://open.spotify.com/artist/5nvWOyAkfNgVLK...           None
# 12  https://open.spotify.com/artist/2hlmm7s2ICUX0L...           None
# 13  https://open.spotify.com/artist/6Ip8FS7vWT1uKk...           None
# 14  https://open.spotify.com/artist/1RyvyyTE3xzB2Z...           None
# 15  https://open.spotify.com/artist/0jPHHnU8GUWEF7...           None
# 16  https://open.spotify.com/artist/6ltzsmQQbmdoHH...           None
# 17  https://open.spotify.com/artist/4Gso3d4CscCijv...           None
# 18  https://open.spotify.com/artist/5JMLG56F1X5mFm...           None
# 19  https://open.spotify.com/artist/0NIPkIjTV8mB79...           None
# 20  https://open.spotify.com/artist/1zO3MgzmcwZLLN...           None
# 21  https://open.spotify.com/artist/3MZsBdqDrRTJih...           None
# 22  https://open.spotify.com/artist/20sxb77xiYeusS...           None
# 23  https://open.spotify.com/artist/6l3HvQ5sa6mXTs...           None
# 24  https://open.spotify.com/artist/7rkW85dBwwrJtl...           None
# 25  https://open.spotify.com/artist/1LKo6ZA3RNvKtL...           None
# 26  https://open.spotify.com/artist/4tuJ0bMpJh08um...           None
# 27  https://open.spotify.com/artist/4lhUHpVOXmkEBG...           None
# 28  https://open.spotify.com/artist/2EMAnMvWE2eb56...           None
# 29  https://open.spotify.com/artist/4G9NDjRyZFDlJK...           None
# 30  https://open.spotify.com/artist/50co4Is1HCEo8b...           None
# 31  https://open.spotify.com/artist/7bXgB6jMjp9ATF...           None
# 32  https://open.spotify.com/artist/5SXuuuRpukkTvs...           None
# 33  https://open.spotify.com/artist/7CajNmpbOovFoO...           None
# 34  https://open.spotify.com/artist/1wRPtKGflJrBx9...           None
# 35  https://open.spotify.com/artist/31TPClRtHm23Ri...           None
# 36  https://open.spotify.com/artist/7FGAlyRveFmDqE...           None
# 37  https://open.spotify.com/artist/0rZp7G3gIH6Wky...           None
# 38  https://open.spotify.com/artist/1URnnhqYAYcrqr...           None
# 39  https://open.spotify.com/artist/1V6rvT87qMQvo6...           None
# 40  https://open.spotify.com/artist/2RQXRUsr4IW1f3...           None
# 41  https://open.spotify.com/artist/3Isy6kedDrgPYo...           None
# 42  https://open.spotify.com/artist/5sK8BsvyDl4TFA...           None
# 43  https://open.spotify.com/artist/687cZJR45JO7jh...           None
# 44  https://open.spotify.com/artist/0eDvMgVFoNV3Tp...           None
# 45  https://open.spotify.com/artist/2h93pZq0e7k5yf...           None
# 46  https://open.spotify.com/artist/0QHgL1lAIqAw0H...           None
# 47  https://open.spotify.com/artist/69tiO1fG8VWduD...           None
# 48  https://open.spotify.com/artist/7IAFAOtc9kTYNT...           None
# 49  https://open.spotify.com/artist/7LVC96BEVGugTA...           None
#
#     followers.total
# 0          98787706
# 1          15873672
# 2           8804719
# 3          11014377
# 4           9091622
# 5          41438871
# 6           7791918
# 7           8511633
# 8           2332320
# 9         105431034
# 10         20541957
# 11          1997805
# 12          9515246
# 13          6136343
# 14         21488546
# 15           307346
# 16          1999079
# 17          6723043
# 18           730071
# 19          2952351
# 20           178115
# 21         10235492
# 22          8184390
# 23         26329939
# 24          3550317
# 25           283365
# 26          5805229
# 27           510653
# 28         10048274
# 29           878452
# 30         11791032
# 31         26514482
# 32          2958738
# 33         23158555
# 34         51071932
# 35         15386396
# 36            71247
# 37          1320629
# 38         22662533
# 39           194035
# 40          4107860
# 41          5139057
# 42           360246
# 43          3149970
# 44         15249619
# 45         18912265
# 46         12043127
# 47           605457
# 48           772086
# 49           429835
